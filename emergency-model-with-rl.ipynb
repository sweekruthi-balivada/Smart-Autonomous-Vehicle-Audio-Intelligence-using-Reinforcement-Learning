# %% [markdown]
# ## Loading the data (Filewise)

# %%
DATA_DIR = "/kaggle/input/emergency-reinforce-learning-data/Emergency_reinforcement_data"   # <-- change to your folder
LABEL_MODE = "by_filename"
SR = 16000
N_MFCC = 13
N_CLUSTERS = 64        # embedding vocab size for tokens
MAX_LEN = 400          # pad/crop token sequence length
BATCH_SIZE = 32
EPOCHS = 30
LR = 1e-3
D_MODEL = 64
N_HEADS = 4
N_LAYERS = 2
HIDDEN_SIZE = 128
PATIENCE = 5           # early stopping patience (epochs)
USE_WEIGHTED_SAMPLER = True
# Out:
# Device: cuda

# %%
import os, re, math, json, random, numpy as np, pandas as pd
from collections import Counter
from pathlib import Path
import librosa
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, WeightedRandomSampler
from sklearn.model_selection import train_test_split
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import (classification_report, confusion_matrix, roc_auc_score,
                             average_precision_score, balanced_accuracy_score, f1_score)
from tqdm.auto import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# %% [markdown]
# ## Data Preparation
# ### Data chunked into MFCCs

# %%
def process_audio_mfcc(file_path, sr=SR, n_mfcc=N_MFCC):
    y, sr = librosa.load(file_path, sr=sr)
    if len(y) < sr:
        y = np.pad(y, (0, sr - len(y)), mode='constant')
    else:
        y = y[:sr]   # 1 second crop for consistency; adjust if needed
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)  # [n_mfcc, time]
    return mfccs.T  # [time, n_mfcc]

def pad_or_crop_1d(arr, max_len, pad_value=0):
    if len(arr) >= max_len:
        return arr[:max_len]
    return np.pad(arr, (0, max_len - len(arr)), constant_values=pad_value)

def infer_label_from_path(path):
    p = Path(path)
    if LABEL_MODE == "by_folder":
        if "ambulance" in p.parent.name.lower():
            return 1
        else:
            return 0
    else:
        # by filename substring
        return 1 if "ambulance" in p.name.lower() else 0

# %%
# Gather file paths
wav_paths = []
for root, _, files in os.walk(DATA_DIR):
    for f in files:
        if f.lower().endswith(".wav"):
            wav_paths.append(os.path.join(root, f))
wav_paths = sorted(wav_paths)
print(f"Found {len(wav_paths)} WAV files")

# Compute MFCCs and labels
all_mfccs = []
all_labels = []
for p in tqdm(wav_paths, desc="MFCCs"):
    mf = process_audio_mfcc(p)  # [T, n_mfcc]
    all_mfccs.append(mf)
    all_labels.append(infer_label_from_path(p))

all_labels = np.array(all_labels)
print("Label counts:", Counter(all_labels))
# Out:
# Found 1165 WAV files
# MFCCs:   0%|          | 0/1165 [00:00<?, ?it/s]
# Label counts: Counter({1: 932, 0: 233})

# %% [markdown]
# ## Splitting of the data

# %%
idx = np.arange(len(wav_paths))
# 70/20/10 split via 80/20 then 12.5% of 80 for val
train_idx, test_idx = train_test_split(idx, test_size=0.2, random_state=42, stratify=all_labels)
train_idx, val_idx = train_test_split(train_idx, test_size=0.125, random_state=42, stratify=all_labels[train_idx])

def subset(arr, ids): return [arr[i] for i in ids]
print("Split sizes:", len(train_idx), len(val_idx), len(test_idx))
print("Train label counts:", Counter(all_labels[train_idx]))
print("Val label counts:",   Counter(all_labels[val_idx]))
print("Test label counts:",  Counter(all_labels[test_idx]))
# Out:
# Split sizes: 815 117 233
# Train label counts: Counter({1: 652, 0: 163})
# Val label counts: Counter({1: 94, 0: 23})
# Test label counts: Counter({1: 186, 0: 47})

# %%
# Fit MiniBatchKMeans on concatenated TRAIN frames (time axis)
train_concat = np.concatenate([all_mfccs[i] for i in train_idx], axis=0)  # [sum_T, n_mfcc]
kmeans = MiniBatchKMeans(n_clusters=N_CLUSTERS, random_state=42, batch_size=8192).fit(train_concat)

def mfcc_to_tokens(mf):   # mf: [T, n_mfcc]
    return kmeans.predict(mf)

def make_token_set(idxs):
    toks = [pad_or_crop_1d(mfcc_to_tokens(all_mfccs[i]), MAX_LEN, 0) for i in idxs]
    labs = all_labels[idxs]
    return torch.tensor(np.stack(toks), dtype=torch.long), torch.tensor(labs, dtype=torch.long)

token_train, label_train = make_token_set(train_idx)
token_val,   label_val   = make_token_set(val_idx)
token_test,  label_test  = make_token_set(test_idx)

print("token_train shape:", token_train.shape, "| label_train shape:", label_train.shape)
print("token_val   shape:", token_val.shape,   "| label_val   shape:", label_val.shape)
print("token_test  shape:", token_test.shape,  "| label_test  shape:", label_test.shape)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# token_train shape: torch.Size([815, 400]) | label_train shape: torch.Size([815])
# token_val   shape: torch.Size([117, 400]) | label_val   shape: torch.Size([117])
# token_test  shape: torch.Size([233, 400]) | label_test  shape: torch.Size([233])

# %% [markdown]
# ## Using weighted sampler to handle imbalance

# %%
train_ds = TensorDataset(token_train, label_train)
val_ds   = TensorDataset(token_val,   label_val)
test_ds  = TensorDataset(token_test,  label_test)

if USE_WEIGHTED_SAMPLER:
    cnt = Counter(label_train.tolist())
    class_w = np.array([1.0 / cnt[0], 1.0 / cnt[1]])
    sample_w = class_w[label_train.numpy()]
    sampler = WeightedRandomSampler(sample_w, num_samples=len(sample_w), replacement=True)
    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, sampler=sampler, drop_last=False)
else:
    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, drop_last=False)

val_loader  = DataLoader(val_ds,  batch_size=BATCH_SIZE, shuffle=False, drop_last=False)
test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)

print("USE_WEIGHTED_SAMPLER =", USE_WEIGHTED_SAMPLER)
# Out:
# USE_WEIGHTED_SAMPLER = True

# %% [markdown]
# ## Emergency Model

# %%
class TransformerEncoder(nn.Module):
    def __init__(self, d_model=D_MODEL, n_heads=N_HEADS, num_layers=N_LAYERS, max_len=MAX_LEN, vocab=N_CLUSTERS):
        super().__init__()
        self.embedding = nn.Embedding(vocab, d_model, padding_idx=0)
        self.pos_encoder = nn.Parameter(torch.zeros(max_len, d_model))
        enc_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=n_heads, batch_first=False)
        self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)

    def forward(self, x):  # x: [B, T]
        emb = self.embedding(x) + self.pos_encoder[:x.size(1)]    # [B,T,D]
        enc = self.encoder(emb.permute(1,0,2))                    # [T,B,D]
        return enc.permute(1,0,2)                                 # [B,T,D]

class SirenClassifier(nn.Module):
    def __init__(self, d_model=D_MODEL, hidden=HIDDEN_SIZE, num_classes=2):
        super().__init__()
        self.backbone = TransformerEncoder(d_model=d_model)
        self.pool = nn.AdaptiveAvgPool1d(1)  # mean over time
        self.fc1 = nn.Linear(d_model, hidden)
        self.act = nn.ReLU()
        self.fc2 = nn.Linear(hidden, num_classes)

    def forward(self, x):  # [B,T]
        h = self.backbone(x)             # [B,T,D]
        h = h.transpose(1,2)             # [B,D,T]
        h = self.pool(h).squeeze(-1)     # [B,D]
        h = self.act(self.fc1(h))
        return self.fc2(h)               # [B,2]

model = SirenClassifier().to(device)

# Class-weighted CE
cnt = Counter(label_train.tolist())
weights = torch.tensor([1.0/cnt[0], 1.0/cnt[1]], dtype=torch.float32).to(device)
criterion = nn.CrossEntropyLoss(weight=weights)
optimizer = torch.optim.AdamW(model.parameters(), lr=LR)
print("Class counts (train):", cnt, "| loss weights:", weights.tolist())
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# Class counts (train): Counter({1: 652, 0: 163}) | loss weights: [0.0061349691823124886, 0.0015337422955781221]

# %% [markdown]
# ## Training the model

# %%
best_val_f1 = -1.0
best_state = None
no_improve = 0

for epoch in range(EPOCHS):
    model.train()
    total_loss = 0.0
    correct = 0
    total = 0
    for x,y in train_loader:
        x = x.to(device); y = y.to(device)
        optimizer.zero_grad()
        logits = model(x)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * y.size(0)

        preds = torch.argmax(logits, dim=1)
        correct += (preds == y).sum().item()
        total += y.size(0)

    train_loss = total_loss / total
    train_acc = correct / total

    # Validation
    model.eval()
    val_probs, val_gts = [], []
    with torch.no_grad():
        for x,y in val_loader:
            x = x.to(device); y = y.to(device)
            logits = model(x)
            p = torch.softmax(logits, dim=1)[:,1].cpu().numpy()
            val_probs.append(p)
            val_gts.append(y.cpu().numpy())
    val_probs = np.concatenate(val_probs); val_gts = np.concatenate(val_gts)

    # choose best threshold by F1
    grid = np.linspace(0.1, 0.9, 17)
    f1s = [f1_score(val_gts, (val_probs>=t).astype(int)) for t in grid]
    best_t = float(grid[int(np.argmax(f1s))])
    val_f1 = float(np.max(f1s))

    print(f"Epoch {epoch+1:02d} | train_loss {train_loss:.4f} | train_acc {train_acc*100:5.1f}% | val_F1 {val_f1:.3f} | best_t {best_t:.2f}")

    if val_f1 > best_val_f1 + 1e-4:
        best_val_f1 = val_f1
        best_state = {
            "model": model.state_dict(),
            "threshold": best_t,
            "epoch": epoch+1
        }
        no_improve = 0
    else:
        no_improve += 1
        if no_improve >= PATIENCE:
            print("Early stopping.")
            break

# Load best
if best_state is not None:
    model.load_state_dict(best_state["model"])
    BEST_T = best_state["threshold"]
else:
    BEST_T = 0.5
print("Chosen threshold (val):", BEST_T)
# Out:
# Epoch 01 | train_loss 0.3748 | train_acc  67.1% | val_F1 0.909 | best_t 0.10
# Epoch 02 | train_loss 0.2773 | train_acc  79.5% | val_F1 0.879 | best_t 0.10
# Epoch 03 | train_loss 0.2324 | train_acc  85.2% | val_F1 0.833 | best_t 0.10
# Epoch 04 | train_loss 0.2327 | train_acc  82.0% | val_F1 0.901 | best_t 0.10
# Epoch 05 | train_loss 0.2049 | train_acc  84.3% | val_F1 0.942 | best_t 0.10
# Epoch 06 | train_loss 0.2066 | train_acc  83.1% | val_F1 0.886 | best_t 0.10
# Epoch 07 | train_loss 0.1486 | train_acc  86.6% | val_F1 0.941 | best_t 0.10
# Epoch 08 | train_loss 0.1678 | train_acc  86.1% | val_F1 0.941 | best_t 0.10
# Epoch 09 | train_loss 0.1558 | train_acc  86.9% | val_F1 0.922 | best_t 0.10
# Epoch 10 | train_loss 0.2078 | train_acc  80.7% | val_F1 0.963 | best_t 0.10
# Epoch 11 | train_loss 0.1518 | train_acc  89.4% | val_F1 0.941 | best_t 0.10
# Epoch 12 | train_loss 0.1605 | train_acc  88.7% | val_F1 0.915 | best_t 0.10
# Epoch 13 | train_loss 0.1470 | train_acc  87.7% | val_F1 0.945 | best_t 0.10
# Epoch 14 | train_loss 0.1160 | train_acc  90.9% | val_F1 0.933 | best_t 0.10
# Epoch 15 | train_loss 0.1385 | train_acc  90.2% | val_F1 0.957 | best_t 0.10
# Early stopping.
# Chosen threshold (val): 0.1

# %% [markdown]
# ## Model evaluation

# %%
def eval_loader(loader, name="Eval"):
    model.eval()
    probs, gts = [], []
    with torch.no_grad():
        for x,y in loader:
            x = x.to(device); y = y.to(device)
            logits = model(x)
            p = torch.softmax(logits, dim=1)[:,1].cpu().numpy()
            probs.append(p); gts.append(y.cpu().numpy())
    probs = np.concatenate(probs); gts = np.concatenate(gts)
    preds = (probs >= BEST_T).astype(int)

    ba = balanced_accuracy_score(gts, preds)
    cm = confusion_matrix(gts, preds)
    try:
        roc = roc_auc_score(gts, probs)
    except Exception:
        roc = float("nan")
    pra = average_precision_score(gts, probs)
    rep = classification_report(gts, preds, digits=3, output_dict=False)

    print(f"\n{name} @ threshold={BEST_T:.2f}")
    print("Balanced Acc:", f"{ba:.3f}")
    print("ROC-AUC:", f"{roc:.3f}")
    print("PR-AUC:", f"{pra:.3f}")
    print("Confusion Matrix:\n", cm)
    print("Classification Report:\n", rep)

eval_loader(val_loader, name="Validation")
eval_loader(test_loader, name="Test")
# Out:
# Validation @ threshold=0.10
# Balanced Acc: 0.892
# ROC-AUC: 0.962
# PR-AUC: 0.991
# Confusion Matrix:
#  [[19  4]
#  [ 4 90]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0      0.826     0.826     0.826        23
#            1      0.957     0.957     0.957        94
#
#     accuracy                          0.932       117
#    macro avg      0.892     0.892     0.892       117
# weighted avg      0.932     0.932     0.932       117
#
#
# Test @ threshold=0.10
# Balanced Acc: 0.840
# ROC-AUC: 0.919
# PR-AUC: 0.974
# Confusion Matrix:
#  [[ 35  12]
#  [ 12 174]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0      0.745     0.745     0.745        47
#            1      0.935     0.935     0.935       186
#
#     accuracy                          0.897       233
#    macro avg      0.840     0.840     0.840       233
# weighted avg      0.897     0.897     0.897       233

# %% [markdown]
# ## ROC Curves and confusion matrices for Val and test sets

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, confusion_matrix

def collect_probs_and_labels(loader):
    model.eval()
    probs, gts = [], []
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device); y = y.to(device)
            logits = model(x)
            p = torch.softmax(logits, dim=1)[:, 1].cpu().numpy()
            probs.append(p); gts.append(y.cpu().numpy())
    return np.concatenate(probs), np.concatenate(gts)

# Collect Validation
val_probs, val_gts = collect_probs_and_labels(val_loader)
# Collect Test
test_probs, test_gts = collect_probs_and_labels(test_loader)

# ROC for Validation
fpr_v, tpr_v, _ = roc_curve(val_gts, val_probs)
roc_auc_v = auc(fpr_v, tpr_v)
plt.figure()
plt.plot(fpr_v, tpr_v, label=f"AUC = {roc_auc_v:.3f}")
plt.plot([0, 1], [0, 1], linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (Validation)")
plt.legend()
plt.show()

# ROC for Test
fpr_t, tpr_t, _ = roc_curve(test_gts, test_probs)
roc_auc_t = auc(fpr_t, tpr_t)
plt.figure()
plt.plot(fpr_t, tpr_t, label=f"AUC = {roc_auc_t:.3f}")
plt.plot([0, 1], [0, 1], linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (Test)")
plt.legend()
plt.show()

# Confusion matrices at BEST_T threshold (picked on Validation during training)
val_preds = (val_probs >= BEST_T).astype(int)
test_preds = (test_probs >= BEST_T).astype(int)
print("Validation Confusion Matrix (threshold =", BEST_T, "):\\n", confusion_matrix(val_gts, val_preds))
print("Test Confusion Matrix (threshold =", BEST_T, "):\\n", confusion_matrix(test_gts, test_preds))
# Out:
# Validation Confusion Matrix (threshold = 0.1 ):\n [[19  4]
#  [ 4 90]]
# Test Confusion Matrix (threshold = 0.1 ):\n [[ 35  12]
#  [ 12 174]]

# %% [markdown]
# ## Saving the model

# %% [markdown]
# ## Saving Emergency Model

# %%
save_path = "/kaggle/working/emergency_reinforcement_model.pth"   # change path/filename as needed
torch.save(model.state_dict(), save_path)
print(f"Model saved to {save_path}")
# Out:
# Model saved to /kaggle/working/emergency_reinforcement_model.pth

# %% [markdown]
# ## Testing the model randomly

# %%
def predict_file(path):
    mf = process_audio_mfcc(path)           # [T, n_mfcc]
    tok = mfcc_to_tokens(mf)                # [T]
    tok = pad_or_crop_1d(tok, MAX_LEN, 0)   # [MAX_LEN]
    x = torch.tensor(tok, dtype=torch.long)[None].to(device)
    with torch.no_grad():
        p = torch.softmax(model(x), dim=1)[:,1].item()
    label = 1 if p >= BEST_T else 0
    return {"proba_siren": float(p), "pred_label": int(label), "threshold": float(BEST_T)}

# Example:
print(predict_file("/kaggle/input/emergency-reinforce-learning-data/Emergency_reinforcement_data/2-102414-B-17.wav"))
print(predict_file("/kaggle/input/emergency-reinforce-learning-data/Emergency_reinforcement_data/ambulance104.wav"))
# Out:
# {'proba_siren': 0.009981492534279823, 'pred_label': 0, 'threshold': 0.1}
# {'proba_siren': 0.9981482028961182, 'pred_label': 1, 'threshold': 0.1}

# %% [markdown]
# ## Reinforcement Learning

# %%
# ==== RL Parameters ====
CHUNK_LEN = 128          # number of tokens per step
CHUNK_HOP = 64           # hop between steps
CONF_HIGH = 0.8          # high-confidence siren prob threshold
NOISE_RMS_HIGH = 0.05    # RMS threshold for high noise
SHORT_DURATION_STEPS = 3 # steps considered "short duration"

# Reward magnitudes
REWARD_ALERT_SIREN_HIGH = 10.0   # S (correct + high conf) and D (early alert)
REWARD_ALERT_SIREN_LOW  = -5.0   # S (wrong/low conf)
REWARD_ALERT_DELAYED    = -1.0   # S/D (delayed alert or delayed while confident siren)
REWARD_NOISE_HIGH       = -1.0   # N (penalize alert in high noise)
REWARD_NOISE_LOW_ALERT  = 0.5    # N (small reward for alert in low noise)
REWARD_OTHERWISE        = 1.0    # small shaping reward
REWARD_MISS_SIREN       = -5.0   # A (missed siren at episode end)

GAMMA = 0.99
TOTAL_TIMESTEPS = 50_000
SEED = 42

import os, numpy as np
from pathlib import Path
import gymnasium as gym
from gymnasium import spaces
import torch
import librosa
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

required = ["model","BEST_T","process_audio_mfcc","mfcc_to_tokens","pad_or_crop_1d","MAX_LEN","device"]
missing = [r for r in required if r not in globals()]
if missing:
    print("WARNING: Missing classifier globals:", missing)
else:
    print("Classifier globals found. Proceeding with RL.")
# Out:
# 2025-09-10 21:58:43.233668: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757541523.502442     120 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757541523.575604     120 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Classifier globals found. Proceeding with RL.

# %% [markdown]
# ## Ensuring if the data and splitting exist or not

# %%
def infer_label_from_path(path):
    p = Path(path)
    name = p.name.lower()
    parent = p.parent.name.lower()
    return 1 if "ambulance" in name or "ambulance" in parent else 0

# Ensure wav_paths and splits exist (fallback uses the same DATA_DIR defined above)
if "wav_paths" not in globals():
    wav_paths = []
    for root, _, files in os.walk(DATA_DIR):
        for f in files:
            if f.lower().endswith(".wav"):
                wav_paths.append(os.path.join(root, f))
    wav_paths = sorted(wav_paths)
    print("Scanned wav_paths:", len(wav_paths))

from sklearn.model_selection import train_test_split
import numpy as np
labels_all = np.array([infer_label_from_path(p) for p in wav_paths])
if "train_idx" not in globals() or "val_idx" not in globals() or "test_idx" not in globals():
    idx = np.arange(len(wav_paths))
    train_idx, test_idx = train_test_split(idx, test_size=0.2, random_state=SEED, stratify=labels_all)
    train_idx, val_idx  = train_test_split(train_idx, test_size=0.125, random_state=SEED, stratify=labels_all[train_idx])
    print("Created splits (fallback):", len(train_idx), len(val_idx), len(test_idx))
else:
    print("Using existing train/val/test indices.")
# Out:
# Using existing train/val/test indices.

# %% [markdown]
# ## Reward policy

# %%
class SirenChunkEnv(gym.Env):
    metadata = {"render_modes": []}
    def __init__(self, file_indices, wav_list,
                 chunk_len=CHUNK_LEN, chunk_hop=CHUNK_HOP,
                 conf_high=CONF_HIGH, noise_rms_high=NOISE_RMS_HIGH,
                 short_steps=SHORT_DURATION_STEPS):
        super().__init__()
        self.wav_list = wav_list
        self.file_indices = list(map(int, file_indices))
        self.chunk_len = chunk_len
        self.chunk_hop = chunk_hop
        self.conf_high = conf_high
        self.noise_rms_high = noise_rms_high
        self.short_steps = short_steps

        self.observation_space = spaces.Box(low=0, high=MAX_LEN, shape=(self.chunk_len,), dtype=np.int64)
        self.action_space = spaces.Discrete(2)  # 0: no alert, 1: alert

        self.cur_file = None
        self.cur_tokens = None
        self.cur_audio = None
        self.cur_label = None
        self.pos = 0
        self.steps_since_reset = 0

    def _file_to_tokens_and_audio(self, path):
        mf = process_audio_mfcc(path)        # [T, n_mfcc]
        toks = mfcc_to_tokens(mf)            # [T]
        y, _ = librosa.load(path, sr=SR if 'SR' in globals() else 16000)
        return toks, y

    def _get_window(self):
        start = self.pos
        end = min(start + self.chunk_len, len(self.cur_tokens))
        window = self.cur_tokens[start:end]
        if len(window) < self.chunk_len:
            window = pad_or_crop_1d(window, self.chunk_len, 0)
        return window

    def _window_rms(self):
        if self.cur_audio is None or len(self.cur_audio) == 0:
            return 0.0
        total_tokens = max(len(self.cur_tokens), 1)
        total_samples = len(self.cur_audio)
        start_tok = self.pos
        end_tok = min(self.pos + self.chunk_len, total_tokens)
        start_s = int(start_tok / total_tokens * total_samples)
        end_s   = int(end_tok   / total_tokens * total_samples)
        end_s   = max(end_s, start_s+1)
        seg = self.cur_audio[start_s:end_s]
        return float(np.sqrt(np.mean(seg**2)))

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        rng = np.random.default_rng(seed if seed is not None else None)
        idx = rng.choice(self.file_indices)
        self.cur_file = self.wav_list[int(idx)]
        self.cur_tokens, self.cur_audio = self._file_to_tokens_and_audio(self.cur_file)
        self.cur_label = infer_label_from_path(self.cur_file)
        self.pos = 0
        self.steps_since_reset = 0
        obs = self._get_window().astype(np.int64)
        return obs, {}

    def step(self, action):
        done = False
        reward = 0.0

        window = self._get_window()
        x = torch.tensor(window, dtype=torch.long, device=device)[None]
        with torch.no_grad():
            prob_siren = torch.softmax(model(x), dim=1)[:,1].item()

        # S: Siren condition
        if action == 1:
            if self.cur_label == 1 and prob_siren >= self.conf_high:
                reward += REWARD_ALERT_SIREN_HIGH
            elif self.cur_label == 0:
                reward += 0.0
            else:
                reward += REWARD_ALERT_SIREN_LOW
        else:
            if self.cur_label == 1 and prob_siren >= BEST_T:
                reward += REWARD_ALERT_DELAYED
            else:
                reward += REWARD_OTHERWISE

        # N: Noise condition
        rms = self._window_rms()
        if action == 1 and rms >= self.noise_rms_high:
            reward += REWARD_NOISE_HIGH
        elif action == 1 and rms < self.noise_rms_high:
            reward += REWARD_NOISE_LOW_ALERT
        else:
            reward += REWARD_OTHERWISE

        # D: Duration condition
        if action == 1:
            if self.steps_since_reset <= self.short_steps:
                reward += REWARD_ALERT_SIREN_HIGH
            else:
                reward += REWARD_ALERT_DELAYED
            done = True  # alert ends the episode

        # progress
        self.pos += self.chunk_hop
        self.steps_since_reset += 1

        # A: Missed siren if end reached with no alert
        if self.pos >= len(self.cur_tokens):
            done = True
            if action == 0 and self.cur_label == 1:
                reward += REWARD_MISS_SIREN

        obs = self._get_window().astype(np.int64)
        return obs, float(reward), done, False, {"prob_siren": prob_siren, "rms": rms, "file": self.cur_file}

# %% [markdown]
# ## Training of the agent

# %%
# Vectorized envs
train_env = DummyVecEnv([lambda: SirenChunkEnv(train_idx, wav_paths)])
val_env   = DummyVecEnv([lambda: SirenChunkEnv(val_idx,   wav_paths)])

dqn = DQN(
    "MlpPolicy", train_env,
    learning_rate=1e-3, buffer_size=50_000, learning_starts=1_000,
    batch_size=64, gamma=GAMMA, train_freq=4, target_update_interval=1_000,
    exploration_fraction=0.2, exploration_final_eps=0.05,
    verbose=1, seed=SEED, tensorboard_log=None
)

dqn.learn(total_timesteps=TOTAL_TIMESTEPS)
dqn.save("siren_dqn_agent_v2")
print("Saved DQN agent to siren_dqn_agent_v2.zip")
# Out:
# Using cuda device
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 23       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 21       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 21       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 23       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 16       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 24       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 20       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 25       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 24       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 25       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 28       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 27       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 32       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 27       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 36       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 28       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 40       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 28       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 44       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 29       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 48       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 29       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 52       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 30       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 56       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 29       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 60       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 30       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 64       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 30       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 68       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 30       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 72       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 30       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 76       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 31       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 80       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 31       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 84       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 31       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 88       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 30       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 92       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 30       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 96       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 30       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 100      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 30       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 104      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 30       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 108      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 30       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 112      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 30       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 116      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 30       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 120      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 30       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 124      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 30       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 128      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 30       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 132      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 30       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 136      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 30       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 140      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 30       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 144      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 30       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 148      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 30       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 152      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 30       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 156      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 31       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 160      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 30       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 164      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 30       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 168      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 31       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 172      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 30       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 176      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 30       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 180      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 31       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 184      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 30       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 188      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 31       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 192      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 31       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 196      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 31       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 200      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 31       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 204      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 31       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 208      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 31       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 212      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 31       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 216      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 31       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 220      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 31       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 224      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 31       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 228      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 31       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 232      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 31       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 236      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 31       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 240      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 31       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 244      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 31       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 248      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 31       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 252      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 31       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 256      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 31       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 260      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 31       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 264      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 31       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 268      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 31       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 272      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 31       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 276      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 31       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 280      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 31       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 284      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 31       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 288      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 31       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 292      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 31       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 296      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 31       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 300      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 31       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 304      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 31       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 308      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 31       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 312      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 31       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 316      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 31       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 320      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 31       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 324      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 31       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 328      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 31       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 332      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 31       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 336      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 31       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 340      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 31       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 344      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 31       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 348      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 31       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 352      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 31       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 356      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 31       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 360      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 31       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 364      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 31       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 368      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 31       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 372      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 31       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 376      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 31       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 380      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 31       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 384      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 31       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 388      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 31       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 392      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 31       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 396      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 31       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 400      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 31       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 404      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 31       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 408      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 31       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 412      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 31       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 416      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 31       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 420      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 31       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 424      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 31       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 428      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 31       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 432      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 31       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 436      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 31       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 440      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 31       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 444      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 31       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 448      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 31       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 452      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 31       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 456      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 31       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 460      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 31       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 464      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 31       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 468      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 31       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 472      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 31       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 476      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 31       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 480      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 31       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 484      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 31       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 488      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 31       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 492      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 31       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 496      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 31       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 500      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 31       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 504      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 31       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 508      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 31       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 512      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 31       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 516      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 31       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 520      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 31       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 524      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 31       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 528      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 31       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 532      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 31       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 536      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 31       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 540      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 31       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 544      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 31       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 548      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 31       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 552      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 31       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 556      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 31       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 560      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 31       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 564      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 31       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 568      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 31       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 572      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 31       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 576      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 31       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 580      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 31       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 584      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 31       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 588      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 31       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 592      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 31       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 596      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 31       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 600      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 31       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 604      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 31       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 608      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    n_updates        | 9919     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40684    |
# |    fps              | 31       |
# |    time_elapsed     | 1312     |
# |    total_timesteps  | 40684    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.394    |
# |    n_updates        | 9920     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40688    |
# |    fps              | 31       |
# |    time_elapsed     | 1312     |
# |    total_timesteps  | 40688    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.862    |
# |    n_updates        | 9921     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40692    |
# |    fps              | 31       |
# |    time_elapsed     | 1312     |
# |    total_timesteps  | 40692    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.83     |
# |    n_updates        | 9922     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40696    |
# |    fps              | 31       |
# |    time_elapsed     | 1312     |
# |    total_timesteps  | 40696    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.09     |
# |    n_updates        | 9923     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40700    |
# |    fps              | 31       |
# |    time_elapsed     | 1312     |
# |    total_timesteps  | 40700    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.06     |
# |    n_updates        | 9924     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40704    |
# |    fps              | 31       |
# |    time_elapsed     | 1312     |
# |    total_timesteps  | 40704    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.14     |
# |    n_updates        | 9925     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40708    |
# |    fps              | 31       |
# |    time_elapsed     | 1312     |
# |    total_timesteps  | 40708    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.984    |
# |    n_updates        | 9926     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40712    |
# |    fps              | 31       |
# |    time_elapsed     | 1313     |
# |    total_timesteps  | 40712    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.695    |
# |    n_updates        | 9927     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40716    |
# |    fps              | 31       |
# |    time_elapsed     | 1313     |
# |    total_timesteps  | 40716    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.725    |
# |    n_updates        | 9928     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40720    |
# |    fps              | 31       |
# |    time_elapsed     | 1313     |
# |    total_timesteps  | 40720    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.81     |
# |    n_updates        | 9929     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40724    |
# |    fps              | 31       |
# |    time_elapsed     | 1313     |
# |    total_timesteps  | 40724    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.701    |
# |    n_updates        | 9930     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40728    |
# |    fps              | 31       |
# |    time_elapsed     | 1313     |
# |    total_timesteps  | 40728    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.9      |
# |    n_updates        | 9931     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40732    |
# |    fps              | 31       |
# |    time_elapsed     | 1313     |
# |    total_timesteps  | 40732    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.826    |
# |    n_updates        | 9932     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40736    |
# |    fps              | 31       |
# |    time_elapsed     | 1313     |
# |    total_timesteps  | 40736    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.05     |
# |    n_updates        | 9933     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40740    |
# |    fps              | 31       |
# |    time_elapsed     | 1314     |
# |    total_timesteps  | 40740    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.997    |
# |    n_updates        | 9934     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40744    |
# |    fps              | 31       |
# |    time_elapsed     | 1314     |
# |    total_timesteps  | 40744    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.76     |
# |    n_updates        | 9935     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40748    |
# |    fps              | 31       |
# |    time_elapsed     | 1314     |
# |    total_timesteps  | 40748    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.753    |
# |    n_updates        | 9936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40752    |
# |    fps              | 31       |
# |    time_elapsed     | 1314     |
# |    total_timesteps  | 40752    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.947    |
# |    n_updates        | 9937     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40756    |
# |    fps              | 31       |
# |    time_elapsed     | 1314     |
# |    total_timesteps  | 40756    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.962    |
# |    n_updates        | 9938     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40760    |
# |    fps              | 31       |
# |    time_elapsed     | 1314     |
# |    total_timesteps  | 40760    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.621    |
# |    n_updates        | 9939     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40764    |
# |    fps              | 31       |
# |    time_elapsed     | 1314     |
# |    total_timesteps  | 40764    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.918    |
# |    n_updates        | 9940     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40768    |
# |    fps              | 31       |
# |    time_elapsed     | 1315     |
# |    total_timesteps  | 40768    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.829    |
# |    n_updates        | 9941     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40772    |
# |    fps              | 31       |
# |    time_elapsed     | 1315     |
# |    total_timesteps  | 40772    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.904    |
# |    n_updates        | 9942     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40776    |
# |    fps              | 31       |
# |    time_elapsed     | 1315     |
# |    total_timesteps  | 40776    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.08     |
# |    n_updates        | 9943     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40780    |
# |    fps              | 31       |
# |    time_elapsed     | 1315     |
# |    total_timesteps  | 40780    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.872    |
# |    n_updates        | 9944     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40784    |
# |    fps              | 31       |
# |    time_elapsed     | 1315     |
# |    total_timesteps  | 40784    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.823    |
# |    n_updates        | 9945     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40788    |
# |    fps              | 31       |
# |    time_elapsed     | 1315     |
# |    total_timesteps  | 40788    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.62     |
# |    n_updates        | 9946     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40792    |
# |    fps              | 31       |
# |    time_elapsed     | 1315     |
# |    total_timesteps  | 40792    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.19     |
# |    n_updates        | 9947     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40796    |
# |    fps              | 31       |
# |    time_elapsed     | 1315     |
# |    total_timesteps  | 40796    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.965    |
# |    n_updates        | 9948     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40800    |
# |    fps              | 31       |
# |    time_elapsed     | 1316     |
# |    total_timesteps  | 40800    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.62     |
# |    n_updates        | 9949     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40804    |
# |    fps              | 31       |
# |    time_elapsed     | 1316     |
# |    total_timesteps  | 40804    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.788    |
# |    n_updates        | 9950     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40808    |
# |    fps              | 31       |
# |    time_elapsed     | 1316     |
# |    total_timesteps  | 40808    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.827    |
# |    n_updates        | 9951     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40812    |
# |    fps              | 31       |
# |    time_elapsed     | 1316     |
# |    total_timesteps  | 40812    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.512    |
# |    n_updates        | 9952     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40816    |
# |    fps              | 31       |
# |    time_elapsed     | 1316     |
# |    total_timesteps  | 40816    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.736    |
# |    n_updates        | 9953     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40820    |
# |    fps              | 31       |
# |    time_elapsed     | 1316     |
# |    total_timesteps  | 40820    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.659    |
# |    n_updates        | 9954     |
# ----------------------------------

# %% [markdown]
# ## Evaluation of DQN Agent

# %%
test_env = DummyVecEnv([lambda: SirenChunkEnv(test_idx, wav_paths)])
mean_r, std_r = evaluate_policy(dqn, test_env, n_eval_episodes=50, deterministic=True)
print(f"Evaluation over 50 episodes — mean reward: {mean_r:.2f} ± {std_r:.2f}")

# One rollout (deterministic)
env = SirenChunkEnv(test_idx, wav_paths)
obs, _ = env.reset()
terminated = truncated = False
steps = 0
cum_r = 0.0
from pathlib import Path
while not (terminated or truncated):
    action, _ = dqn.predict(obs, deterministic=True)
    obs, r, terminated, truncated, info = env.step(int(action))
    steps += 1
    cum_r += r
    if action == 1:
        print(f"[STEP {steps}] ALERT | prob={info['prob_siren']:.3f} | rms={info['rms']:.4f} | r={r:.2f} | file={Path(info['file']).name}")
    else:
        print(f"[STEP {steps}] no alert | prob={info['prob_siren']:.3f} | rms={info['rms']:.4f} | r={r:.2f}")
print("Episode done. Total reward:", cum_r)
# Out:
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Evaluation over 50 episodes — mean reward: 14.08 ± 6.13
# [STEP 1] ALERT | prob=0.995 | rms=0.2186 | r=19.00 | file=ambulance817.wav
# Episode done. Total reward: 19.0

# %% [markdown]
# ## Evaluating the Agent over 200 episodes and generating a learning curve

# %%
from gymnasium import spaces
import numpy as np, torch, librosa

class SirenChunkEnvV2(SirenChunkEnv):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        # episode accumulators
        self._ep_return = 0.0
        self._ep_len = 0
        self._ep_s = 0.0
        self._ep_n = 0.0
        self._ep_d = 0.0
        self._ep_a = 0.0

    def reset(self, seed=None, options=None):
        obs, info = super().reset(seed=seed, options=options)
        self._ep_return = 0.0
        self._ep_len = 0
        self._ep_s = 0.0
        self._ep_n = 0.0
        self._ep_d = 0.0
        self._ep_a = 0.0
        return obs, info

    def step(self, action):
        done = False
        info = {}

        # --- compute components (S, N, D, A) separately ---
        # classifier probability
        window = self._get_window()
        x = torch.tensor(window, dtype=torch.long, device=device)[None]
        with torch.no_grad():
            prob_siren = torch.softmax(model(x), dim=1)[:,1].item()

        # S: siren correctness/confidence
        s_r = 0.0
        if action == 1:
            if self.cur_label == 1 and prob_siren >= self.conf_high:
                s_r += REWARD_ALERT_SIREN_HIGH
            elif self.cur_label == 0:
                s_r += 0.0
            else:
                s_r += REWARD_ALERT_SIREN_LOW
        else:
            if self.cur_label == 1 and prob_siren >= BEST_T:
                s_r += REWARD_ALERT_DELAYED
            else:
                s_r += REWARD_OTHERWISE

        # N: noise effect
        rms = self._window_rms()
        n_r = 0.0
        if action == 1 and rms >= self.noise_rms_high:
            n_r += REWARD_NOISE_HIGH
        elif action == 1 and rms < self.noise_rms_high:
            n_r += REWARD_NOISE_LOW_ALERT
        else:
            n_r += REWARD_OTHERWISE

        # D: timeliness
        d_r = 0.0
        if action == 1:
            if self.steps_since_reset <= self.short_steps:
                d_r += REWARD_ALERT_SIREN_HIGH
            else:
                d_r += REWARD_ALERT_DELAYED
            done = True  # episode ends on alert

        # Progress
        self.pos += self.chunk_hop
        self.steps_since_reset += 1

        # A: missed siren at end
        a_r = 0.0
        if self.pos >= len(self.cur_tokens):
            done = True
            if action == 0 and self.cur_label == 1:
                a_r += REWARD_MISS_SIREN

        reward = float(s_r + n_r + d_r + a_r)

        # Update accumulators
        self._ep_return += reward
        self._ep_len += 1
        self._ep_s += s_r
        self._ep_n += n_r
        self._ep_d += d_r
        self._ep_a += a_r

        obs = self._get_window().astype(np.int64)
        info.update({
            "prob_siren": prob_siren,
            "rms": rms,
            "file": self.cur_file
        })
        if done:
            info.update({
                "episode_return": self._ep_return,
                "episode_length": self._ep_len,
                "ep_s": self._ep_s,
                "ep_n": self._ep_n,
                "ep_d": self._ep_d,
                "ep_a": self._ep_a,
                "label": int(self.cur_label),
            })
        return obs, reward, done, False, info

# %%
from stable_baselines3.common.callbacks import BaseCallback

class EpisodeStatsCallback(BaseCallback):
    def __init__(self):
        super().__init__()
        self.episode_returns = []
        self.episode_lengths = []
        self.ep_s = []
        self.ep_n = []
        self.ep_d = []
        self.ep_a = []

    def _on_step(self) -> bool:
        infos = self.locals.get("infos", [])
        for info in infos:
            if "episode_return" in info:  # episode finished for this env
                self.episode_returns.append(info["episode_return"])
                self.episode_lengths.append(info["episode_length"])
                self.ep_s.append(info.get("ep_s", 0.0))
                self.ep_n.append(info.get("ep_n", 0.0))
                self.ep_d.append(info.get("ep_d", 0.0))
                self.ep_a.append(info.get("ep_a", 0.0))
        return True

stats_cb = EpisodeStatsCallback()

# %%
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv

log_train_env = DummyVecEnv([lambda: SirenChunkEnvV2(train_idx, wav_paths)])
dqn_log = DQN(
    "MlpPolicy", log_train_env,
    learning_rate=1e-3, buffer_size=50_000, learning_starts=1_000,
    batch_size=64, gamma=GAMMA, train_freq=4, target_update_interval=1_000,
    exploration_fraction=0.2, exploration_final_eps=0.05,
    verbose=0, seed=SEED, tensorboard_log=None
)

# warm-start from the previously trained agent if available
try:
    dqn_log.load("siren_dqn_agent_v2", env=log_train_env)
    print("Loaded weights from siren_dqn_agent_v2.zip")
except Exception as e:
    print("Fresh RL training (no prior agent found):", e)

# Train a bit more to gather stats (adjust timesteps as needed)
ADDITIONAL_TIMESTEPS = 20_000
dqn_log.learn(total_timesteps=ADDITIONAL_TIMESTEPS, callback=stats_cb)
print(f"Collected {len(stats_cb.episode_returns)} episodes during logging run.")
# Out:
# Loaded weights from siren_dqn_agent_v2.zip
# Collected 20000 episodes during logging run.

# %% [markdown]
# ## Plotting the learning curve

# %%
import matplotlib.pyplot as plt
import numpy as np

def rolling_stats(x, window=50):
    x = np.asarray(x, dtype=float)
    if len(x) == 0:
        return np.array([]), np.array([])
    means, stds = [], []
    for i in range(len(x)):
        lo = max(0, i - window + 1)
        seg = x[lo:i+1]
        means.append(np.mean(seg))
        stds.append(np.std(seg))
    return np.array(means), np.array(stds)

fig, axs = plt.subplots(3, 1, figsize=(10, 12))

# 1) Learning curve (only smoothed)
ret = stats_cb.episode_returns
m, s = rolling_stats(ret, window=50)
axs[0].plot(m, label="Rolling mean (50)", color="orange")
axs[0].fill_between(np.arange(len(m)), m - s, m + s, alpha=0.2, color="orange", label="±1 std")
axs[0].set_xlabel("Episode")
axs[0].set_ylabel("Return")
axs[0].set_title("Learning Curve: Episode Return")
axs[0].legend()

# 2) Episode length (only smoothed)
elens = stats_cb.episode_lengths
mL, sL = rolling_stats(elens, window=50)
axs[1].plot(mL, label="Rolling mean (50)", color="green")
axs[1].fill_between(np.arange(len(mL)), mL - sL, mL + sL, alpha=0.2, color="green", label="±1 std")
axs[1].set_xlabel("Episode")
axs[1].set_ylabel("Length (steps)")
axs[1].set_title("Episode Length Over Time")
axs[1].legend()

# 3) Reward breakdown (S/N/D/A, smoothed only)
s_m, _ = rolling_stats(stats_cb.ep_s, window=50)
n_m, _ = rolling_stats(stats_cb.ep_n, window=50)
d_m, _ = rolling_stats(stats_cb.ep_d, window=50)
a_m, _ = rolling_stats(stats_cb.ep_a, window=50)
axs[2].plot(s_m, label="S (Siren)")
axs[2].plot(n_m, label="N (Noise)")
axs[2].plot(d_m, label="D (Duration)")
axs[2].plot(a_m, label="A (Miss/Alert)")
axs[2].set_xlabel("Episode")
axs[2].set_ylabel("Reward (rolling mean)")
axs[2].set_title("Reward Breakdown (S/N/D/A)")
axs[2].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Saving the Emergency siren AGENT

# %%
# Save the DQN agent
dqn_save_path = "/kaggle/working/emergency_siren_dqn_agent"
dqn.save(dqn_save_path)
print(f"DQN agent saved to {dqn_save_path}.zip")
# Out:
# DQN agent saved to /kaggle/working/emergency_siren_dqn_agent.zip
